# %% [markdown]
# ## Import

# %%
import pandas as pd

# %% [markdown]
# ## import data

# %%
data = pd.read_csv(f'C:/Users/pipatra.NSN-INTRA/Desktop/Anaconda/Projects/21-Sept/Rapido(Like_uber)/data/clean_data.csv')

# %%
data.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   14626        True       False             False           False
# 1   85490        True       False             False           False
# 2    5408        True       False             False           False
# 3   58940        True       False             False           False
# 4    5408        True       False             False           False
#
#    is_weednesday  is_holiday        date
# 0          False       False  2018-04-07
# 1          False       False  2018-04-07
# 2          False       False  2018-04-07
# 3          False       False  2018-04-07
# 4          False       False  2018-04-07

# %% [markdown]
# - target variable is missing

# %% [markdown]
# ## 83997

# %%
selected_user = 83997
user = data[data.number == selected_user].reset_index(drop=True)
user.head()
# Out:
#    number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0   83997        True       False             False           False
# 1   83997        True       False             False           False
# 2   83997       False        True              True           False
# 3   83997       False        True              True           False
# 4   83997       False        True              True           False
#
#    is_weednesday  is_holiday        date
# 0          False       False  2018-04-07
# 1          False       False  2018-04-07
# 2          False       False  2018-04-09
# 3          False       False  2018-04-09
# 4          False       False  2018-04-09

# %%
user.shape
# Out:
# (3652, 8)

# %%
user.drop_duplicates('date',inplace=True)

# %%
user.head()
# Out:
#     number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0    83997        True       False             False           False
# 2    83997       False        True              True           False
# 10   83997       False        True              True           False
# 31   83997       False        True             False           False
# 33   83997       False        True             False            True
#
#     is_weednesday  is_holiday        date
# 0           False       False  2018-04-07
# 2           False       False  2018-04-09
# 10          False       False  2018-04-10
# 31           True       False  2018-04-11
# 33          False       False  2018-04-12

# %%
user.shape
# Out:
# (329, 8)

# %%
user['booking_class'] = 1

# %%
user.head()
# Out:
#     number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0    83997        True       False             False           False
# 2    83997       False        True              True           False
# 10   83997       False        True              True           False
# 31   83997       False        True             False           False
# 33   83997       False        True             False            True
#
#     is_weednesday  is_holiday        date  booking_class
# 0           False       False  2018-04-07              1
# 2           False       False  2018-04-09              1
# 10          False       False  2018-04-10              1
# 31           True       False  2018-04-11              1
# 33          False       False  2018-04-12              1

# %%
user.date.max()
# Out:
# '2019-04-06'

# %%
user.date.min()
# Out:
# '2018-04-07'

# %% [markdown]
# ## Create New Data Frame

# %%
user_continuous_date=pd.date_range(start='2018-04-07',end='2019-04-06')

# %%
user_continuous_date
# Out:
# DatetimeIndex(['2018-04-07', '2018-04-08', '2018-04-09', '2018-04-10',
#                '2018-04-11', '2018-04-12', '2018-04-13', '2018-04-14',
#                '2018-04-15', '2018-04-16',
#                ...
#                '2019-03-28', '2019-03-29', '2019-03-30', '2019-03-31',
#                '2019-04-01', '2019-04-02', '2019-04-03', '2019-04-04',
#                '2019-04-05', '2019-04-06'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
user_83997 = pd.DataFrame(user_continuous_date,columns=['user_continuous_date'])

# %%
user_83997.head()
# Out:
#   user_continuous_date
# 0           2018-04-07
# 1           2018-04-08
# 2           2018-04-09
# 3           2018-04-10
# 4           2018-04-11

# %%
user_83997.user_continuous_date = user_83997.user_continuous_date.astype('datetime64[ns]')

# %%
user_83997.dtypes
# Out:
# user_continuous_date    datetime64[ns]
# dtype: object

# %%
user_83997.user_continuous_date.dt.dayofweek
# Out:
# 0      5
# 1      6
# 2      0
# 3      1
# 4      2
# 5      3
# 6      4
# 7      5
# 8      6
# 9      0
# 10     1
# 11     2
# 12     3
# 13     4
# 14     5
# 15     6
# 16     0
# 17     1
# 18     2
# 19     3
# 20     4
# 21     5
# 22     6
# 23     0
# 24     1
# 25     2
# 26     3
# 27     4
# 28     5
# 29     6
#       ..
# 335    4
# 336    5
# 337    6
# 338    0
# 339    1
# 340    2
# 341    3
# 342    4
# 343    5
# 344    6
# 345    0
# 346    1
# 347    2
# 348    3
# 349    4
# 350    5
# 351    6
# 352    0
# 353    1
# 354    2
# 355    3
# 356    4
# 357    5
# 358    6
# 359    0
# 360    1
# 361    2
# 362    3
# 363    4
# 364    5
# Name: user_continuous_date, Length: 365, dtype: int64

# %%
user_83997['number'] = selected_user
user_83997['is_weekend'] = user_83997.user_continuous_date.dt.dayofweek.isin([5,6])

# %%
user_83997.head()
# Out:
#   user_continuous_date  number  is_weekend
# 0           2018-04-07   83997        True
# 1           2018-04-08   83997        True
# 2           2018-04-09   83997       False
# 3           2018-04-10   83997       False
# 4           2018-04-11   83997       False

# %%
user_83997['is_weekday'] = user_83997.user_continuous_date.dt.dayofweek.isin([0,1,2,3,4])
user_83997['is_start_of_week'] = user_83997.user_continuous_date.dt.dayofweek.isin([0,1])
user_83997['is_weednesday'] = user_83997.user_continuous_date.dt.dayofweek.isin([2])
user_83997.head()
# Out:
#   user_continuous_date  number  is_weekend  is_weekday  is_start_of_week  \
# 0           2018-04-07   83997        True       False             False
# 1           2018-04-08   83997        True       False             False
# 2           2018-04-09   83997       False        True              True
# 3           2018-04-10   83997       False        True              True
# 4           2018-04-11   83997       False        True             False
#
#    is_weednesday
# 0          False
# 1          False
# 2          False
# 3          False
# 4           True

# %%
holiday = pd.read_csv(f'C:/Users/pipatra.NSN-INTRA/Desktop/Anaconda/Projects/21-Sept/Rapido(Like_uber)/data/Holiday.csv')

# %%
user_83997['user_continuous_date'] = user_83997.user_continuous_date.dt.date

# %%
user_83997['is_holiday'] = user_83997.user_continuous_date.isin(holiday.DATE)

# %%
user_83997['booking_class'] = 0

# %%
user_83997.head()
# Out:
#   user_continuous_date  number  is_weekend  is_weekday  is_start_of_week  \
# 0           2018-04-07   83997        True       False             False
# 1           2018-04-08   83997        True       False             False
# 2           2018-04-09   83997       False        True              True
# 3           2018-04-10   83997       False        True              True
# 4           2018-04-11   83997       False        True             False
#
#    is_weednesday  is_holiday  booking_class
# 0          False       False              0
# 1          False       False              0
# 2          False       False              0
# 3          False       False              0
# 4           True       False              0

# %%
user_83997 = user_83997[~user_83997.user_continuous_date.isin(user.date)]

# %%
user_83997.head()
# Out:
#   user_continuous_date  number  is_weekend  is_weekday  is_start_of_week  \
# 0           2018-04-07   83997        True       False             False
# 1           2018-04-08   83997        True       False             False
# 2           2018-04-09   83997       False        True              True
# 3           2018-04-10   83997       False        True              True
# 4           2018-04-11   83997       False        True             False
#
#    is_weednesday  is_holiday  booking_class
# 0          False       False              0
# 1          False       False              0
# 2          False       False              0
# 3          False       False              0
# 4           True       False              0

# %%
user.dtypes
# Out:
# number               int64
# is_weekend            bool
# is_weekday            bool
# is_start_of_week      bool
# is_end_of_week        bool
# is_weednesday         bool
# is_holiday            bool
# date                object
# booking_class        int64
# dtype: object

# %%
user_83997.dtypes
# Out:
# user_continuous_date    object
# number                   int64
# is_weekend                bool
# is_weekday                bool
# is_start_of_week          bool
# is_weednesday             bool
# is_holiday                bool
# booking_class            int64
# dtype: object

# %%
user.head()
# Out:
#     number  is_weekend  is_weekday  is_start_of_week  is_end_of_week  \
# 0    83997        True       False             False           False
# 2    83997       False        True              True           False
# 10   83997       False        True              True           False
# 31   83997       False        True             False           False
# 33   83997       False        True             False            True
#
#     is_weednesday  is_holiday        date  booking_class
# 0           False       False  2018-04-07              1
# 2           False       False  2018-04-09              1
# 10          False       False  2018-04-10              1
# 31           True       False  2018-04-11              1
# 33          False       False  2018-04-12              1

# %%
user_83997.rename(columns={"user_continuous_date":"date"},inplace=True)

# %%
complete_data = pd.merge(user,user_83997,how='outer')
complete_data.head()
# Out:
#    number is_weekend is_weekday is_start_of_week is_end_of_week is_weednesday  \
# 0   83997       True      False            False          False         False
# 1   83997      False       True             True          False         False
# 2   83997      False       True             True          False         False
# 3   83997      False       True            False          False          True
# 4   83997      False       True            False           True         False
#
#   is_holiday        date  booking_class
# 0      False  2018-04-07              1
# 1      False  2018-04-09              1
# 2      False  2018-04-10              1
# 3      False  2018-04-11              1
# 4      False  2018-04-12              1

# %%
complete_data.dtypes
complete_data.date = complete_data.date.astype('datetime64[ns]')

# %%
complete_data.sort_values(by='date')
# Out:
#      number is_weekend is_weekday is_start_of_week is_end_of_week  \
# 0     83997       True      False            False          False
# 329   83997       True      False            False            NaN
# 330   83997       True      False            False            NaN
# 1     83997      False       True             True          False
# 331   83997      False       True             True            NaN
# 2     83997      False       True             True          False
# 332   83997      False       True             True            NaN
# 333   83997      False       True            False            NaN
# 3     83997      False       True            False          False
# 334   83997      False       True            False            NaN
# 4     83997      False       True            False           True
# 335   83997      False       True            False            NaN
# 5     83997      False       True            False           True
# ...

# %% [markdown]
# ## Todo
#
# - drop number and date
# - write it back to file
# - apply different algorithms what you learnt in ML class

# %%
complete_data.drop(['date','number'],axis=1,inplace=True)

# %%
complete_data.head()
# Out:
#   is_weekend is_weekday is_start_of_week is_end_of_week is_weednesday  \
# 0       True      False            False          False         False
# 1      False       True             True          False         False
# 2      False       True             True          False         False
# 3      False       True            False          False          True
# 4      False       True            False           True         False
#
#   is_holiday  booking_class
# 0      False              1
# 1      False              1
# 2      False              1
# 3      False              1
# 4      False              1

# %%
complete_data.to_csv(f'C:/Users/pipatra.NSN-INTRA/Desktop/Anaconda/Projects/21-Sept/Rapido(Like_uber)/data/ML_Data_Rapido.csv',index=False)
